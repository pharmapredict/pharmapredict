# %% [markdown]
# # Preparing API calls code for webapp

# %% [markdown]
# input: pandas dataframe with INN, therapeutic areas and current date
#
# output: input dataframe with additional columns on trial data and pubmed conclusions

# %%
import pandas as pd
from pharmatools.clinical_trials import get_trial_data
from pharmatools.pubmed import get_pubmed_ids, get_titles_abstracts_batch
from nltk.tokenize import sent_tokenize
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Defining functions

# %%
def trial_data(df):
    # convert to datetime
    df['First published'] = pd.to_datetime(df['First published'])

    # prepare dataframe
    df['n_trials'] = 0
    df['status_not_yet_recruiting'] = 0
    df['status_recruiting'] = 0
    df['status_enrolling_by_invitation'] = 0
    df['status_active_not_recruiting'] = 0
    df['status_suspended'] = 0
    df['status_terminated'] = 0
    df['status_completed'] = 0
    df['status_withdrawn'] = 0
    df['status_unknown'] = 0

    df['org_fed'] = 0
    df['org_indiv'] = 0
    df['org_industry'] = 0
    df['org_network'] = 0
    df['org_nih'] = 0
    df['org_other'] = 0
    df['org_other_gov'] = 0

    df['phase_early_1'] = 0
    df['phase_not_applicable'] = 0
    df['phase_1'] = 0
    df['phase_2'] = 0
    df['phase_3'] = 0
    df['phase_4'] = 0

    # pull data from API into dataframe
    for index, row in df.iterrows():

        print(f'fetching trial data for {index}, {row["INN"]}')

        # call ClinicalTrials API
        try:
            data = get_trial_data(row['INN'], row['Therapeutic area'], row['First published'])

            # update dataframe
            df['n_trials'][index] = data['n_trials']

            df['status_not_yet_recruiting'][index] = data['status']['Not yet recruiting']
            df['status_recruiting'][index] = data['status']['Recruiting']
            df['status_enrolling_by_invitation'][index] = data['status']['Enrolling by invitation']
            df['status_active_not_recruiting'][index] = data['status']['Active, not recruiting']
            df['status_suspended'][index] = data['status']['Suspended']
            df['status_terminated'][index] = data['status']['Terminated']
            df['status_completed'][index] = data['status']['Completed']
            df['status_withdrawn'][index] = data['status']['Withdrawn']
            df['status_unknown'][index] = data['status']['Unknown status']

            df['org_fed'][index] = data['organizers']['FED']
            df['org_indiv'][index] = data['organizers']['INDIV']
            df['org_industry'][index] = data['organizers']['INDUSTRY']
            df['org_network'][index] = data['organizers']['NETWORK']
            df['org_nih'][index] = data['organizers']['NIH']
            df['org_other'][index] = data['organizers']['OTHER']
            df['org_other_gov'][index] = data['organizers']['OTHER_GOV']

            df['phase_early_1'][index] = data['phases']['Early Phase 1']
            df['phase_not_applicable'][index] = data['phases']['Not Applicable']
            df['phase_1'][index] = data['phases']['Phase 1']
            df['phase_2'][index] = data['phases']['Phase 2']
            df['phase_3'][index] = data['phases']['Phase 3']
            df['phase_4'][index] = data['phases']['Phase 4']
        except:
            raise f"fetching trial data for {index} not successful"

    return df

# %%
def pubmed_abstracts(df):
    df_abstracts = pd.DataFrame(columns=['id', 'abstract'])
    df["pm_results"] = 0
    
    for index, row in df.iterrows():
        print(f"index: {index}, INN: {row['INN']}")
        ids = get_pubmed_ids(row['INN'], row['Therapeutic area'], row['First published'])
        n_ids = len(ids)
        print(f'results: {n_ids}')
        df['pm_results'][index] = n_ids
        
        # fetch abstracts of first 200 results
        titles, abstracts = get_titles_abstracts_batch(ids[:200])
        print(f'# of abstracts: {len(abstracts)}')
        for abstract in abstracts:
            df_abstracts = df_abstracts.append(pd.DataFrame.from_dict({'id': [index], 'abstract': [abstract]}), ignore_index=True)
        print('')
        
        return df_abstracts

# %%
def n_last_senteces(text, n):
    return ' '.join(sent_tokenize(text)[-n:])

# %%
def pubmed_conclusions(df):
    df_abstracts = pubmed_abstracts(df)
    
    df["conclusions"] = ""
    for index, row in df.iterrows():
        print(index)
        conclusions = ""
        for _, row_abstr in df_abstracts.loc[df_abstracts['id'] == index].iterrows():
            conclusion = n_last_senteces(row_abstr['abstract'], 2)
            conclusions += " " + conclusion
        df['conclusions'][index] = conclusions    
    
    return df

# %% [markdown]
# ## testing

# %%
df = pd.DataFrame.from_dict({"INN": "rivaroxaban",
                  "Therapeutic area": "pulmonary embolism, TVT",
                  "First published": "2018-01-01"},
                           orient="index")

# %%
df = df.T

# %%
df
# Out:
#            INN         Therapeutic area First published
# 0  rivaroxaban  pulmonary embolism, TVT      2018-01-01

# %%
df = trial_data(df)
# Out:
# fetching trial data for 0, rivaroxaban
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#            INN         Therapeutic area First published  n_trials  \
# 0  rivaroxaban  pulmonary embolism, TVT      2018-01-01       118
#
#    status_not_yet_recruiting  status_recruiting  \
# 0                          8                 24
#
#    status_enrolling_by_invitation  status_active_not_recruiting  \
# 0                               1                             9
#
#    status_suspended  status_terminated  ...  org_network  org_nih  org_other  \
# 0                 1                  4  ...            0        0         72
#
#    org_other_gov  phase_early_1  phase_not_applicable  phase_1  phase_2  \
# 0              2              0                    10        1       15
#
#    phase_3  phase_4
# 0       41       14
#
# [1 rows x 26 columns]

# %%
df_abstracts = pubmed_data(df)
# Out:
# index: 0, INN: rivaroxaban
# results: 524
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# no abstract
# no abstract
# # of abstracts: 172

# %%
df_abstracts
# Out:
#     id                                           abstract
# 0    0  We sought to compare the length of stay (LOS) ...
# 1    0  Thrombosis after cessation of anticoagulation,...
# 2    0
# 3    0  To compare hospital length of stay (LOS) and h...
# 4    0  We sought to compare length-of-stay (LOS), tot...
# 5    0  Due to limited evidence on the impact of rivar...
# 6    0  Pulmonary embolism (PE) is a life-threatening ...
# 7    0  Pulmonary embolism remains one of the leading ...
# 8    0  In the EINSTEIN-Pulmonary Embolism (PE) trial,...
# 9    0  Pulmonary embolism (PE) is a potentially life-...
# 10   0  Unlike rivaroxaban, treatment of patients with...
# 11   0  Venous thromboembolism (VTE), comprising deep-...
# 12   0  Using real-world data, this study compares inp...
# 13   0  Imaging work-up of a 80-year-old woman with su...
# 14   0  Depending on the severity of clinical conditio...
# 15   0  Rivaroxaban is an oral, direct Factor Xa inhib...
# 16   0  In Japan, the standard of care for the treatme...
# 17   0  Thrombolysis, though very effective, has not b...
# 18   0  Traditionally, patients with pulmonary embolis...
# 19   0  The objective was to assess adverse outcomes i...
# 20   0  Cytomegalovirus (CMV) infection is a common di...
# 21   0  Heparin-induced thrombocytopenia (HIT) is a li...
# 22   0  A short cut review was carried out to establis...
# 23   0  A fixed-dose regimen of rivaroxaban, an oral f...
# 24   0  Non-steroidal anti-inflammatory drugs have bee...
# 25   0  The phase III EINSTEIN DVT and EINSTEIN PE tri...
# 26   0  Rivaroxaban (Xarelto(®)), an oral direct facto...
# 27   0  To establish the rat model of acute pulmonary ...
# 28   0  Pulmonary embolism is a potentially life-threa...
# 29   0  Pulmonary embolism (PE) affects >600,000 patie...
# ..  ..                                                ...
# 142  0  To evaluate the safety of uninterrupted rivaro...
# 143  0  The purpose of this study is to evaluate the e...
# 144  0  Atrial fibrillation is the most common cardiac...
# 145  0  Rivaroxaban is a once-daily oral anticoagulant...
# 146  0  Rivaroxaban is a direct oral anticoagulant tar...
# 147  0  Based on different mechanisms of blood coagula...
# 148  0  Venous thromboembolism (VTE) is the most wides...
# 149  0  Patients with unprovoked venous thromboembolis...
# 150  0  Anticoagulation with low molecular weight hepa...
# 151  0  Multiple randomized controlled trials have doc...
# 152  0  Background Direct oral anticoagulants (DOACs) ...
# 153  0  Hypercoagulability, resulting in thromboemboli...
# 154  0  Arterial and venous thrombotic states, includi...
# 155  0  Little is known about the natural history of c...
# 156  0  The effectiveness of preoperative thromboproph...
# 157  0  Pulmonary embolism is a common, potentially fa...
# 158  0  Although data from the Regulation of Coagulati...
# 159  0  Rivaroxaban is the first licensed oral direct ...
# 160  0  Nonvitamin K antagonist oral anticoagulants, p...
# 161  0  Pulmonary embolism (PE), which can develop as ...
# 162  0  Venous thromboembolism (VTE) is a common disea...
# 163  0  Rivaroxaban is the first agent available withi...
# 164  0  Rivaroxaban is the first oral factor Xa inhibi...
# 165  0  Deep-vein thrombosis and subsequent pulmonary ...
# 166  0  Venous thromboembolism (VTE), comprised of dee...
# 167  0  Patients with acute medical illnesses are at i...
# 168  0  Dabigatran and rivaroxaban are new oral antico...
# 169  0  The incidence of venous thromboembolism (VTE),...
# 170  0  Rivaroxaban (BAY 59-7939) is an oral, direct f...
# 171  0  Historically, warfarin or aspirin have been th...
#
# [172 rows x 2 columns]

# %%
df = pubmed_conclusions(df)
# Out:
# index: 0, INN: rivaroxaban
# results: 524
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# no abstract
# no abstract
# # of abstracts: 172
#
# 0
# c:\users\lukas\.venvs\lewagon\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df
# Out:
#            INN         Therapeutic area First published  n_trials  \
# 0  rivaroxaban  pulmonary embolism, TVT      2018-01-01       118
#
#    status_not_yet_recruiting  status_recruiting  \
# 0                          8                 24
#
#    status_enrolling_by_invitation  status_active_not_recruiting  \
# 0                               1                             9
#
#    status_suspended  status_terminated  ...  org_other  org_other_gov  \
# 0                 1                  4  ...         72              2
#
#    phase_early_1  phase_not_applicable  phase_1  phase_2  phase_3  phase_4  \
# 0              0                    10        1       15       41       14
#
#    pm_results                                        conclusions
# 0         524   In analyses restricted to low-risk patients (...
#
# [1 rows x 28 columns]

# %%
from utils.clinical_trials_pubmed import ct_pm

# %%
df = pd.DataFrame.from_dict({"INN": "rivaroxaban",
                  "Therapeutic area": "pulmonary embolism, TVT",
                  "First published": "2018-01-01"},
                           orient="index").T

# %%
df = ct_pm(df)
# Out:
# fetching trial data for 0, rivaroxaban
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['n_trials'][index] = data['n_trials']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_not_yet_recruiting'][index] = data['status']['Not yet recruiting']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_recruiting'][index] = data['status']['Recruiting']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_enrolling_by_invitation'][index] = data['status']['Enrolling by invitation']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_active_not_recruiting'][index] = data['status']['Active, not recruiting']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_suspended'][index] = data['status']['Suspended']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_terminated'][index] = data['status']['Terminated']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_completed'][index] = data['status']['Completed']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_withdrawn'][index] = data['status']['Withdrawn']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['status_unknown'][index] = data['status']['Unknown status']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_fed'][index] = data['organizers']['FED']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_indiv'][index] = data['organizers']['INDIV']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_industry'][index] = data['organizers']['INDUSTRY']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_network'][index] = data['organizers']['NETWORK']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_nih'][index] = data['organizers']['NIH']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_other'][index] = data['organizers']['OTHER']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['org_other_gov'][index] = data['organizers']['OTHER_GOV']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['phase_early_1'][index] = data['phases']['Early Phase 1']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['phase_not_applicable'][index] = data['phases']['Not Applicable']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['phase_1'][index] = data['phases']['Phase 1']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['phase_2'][index] = data['phases']['Phase 2']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['phase_3'][index] = data['phases']['Phase 3']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['phase_4'][index] = data['phases']['Phase 4']
# c:\users\lukas\.venvs\lewagon\lib\site-packages\Bio\Entrez\__init__.py:670: UserWarning:
# Email address is not specified.
#
# To make use of NCBI's E-utilities, NCBI requires you to specify your
# email address with each request.  As an example, if your email address
# is A.N.Other@example.com, you can specify it as follows:
#    from Bio import Entrez
#    Entrez.email = 'A.N.Other@example.com'
# In case of excessive usage of the E-utilities, NCBI will attempt to contact
# a user at the email address provided before blocking access to the
# E-utilities.
#   UserWarning,
# index: 0, INN: rivaroxaban
# results: 524
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['pm_results'][index] = n_ids
# no abstract
# no abstract
# # of abstracts: 172
#
# 0
# c:\users\lukas\.venvs\lewagon\lib\site-packages\utils\clinical_trials_pubmed.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['conclusions'][index] = conclusions

# %%
df
# Out:
#            INN         Therapeutic area First published  n_trials  \
# 0  rivaroxaban  pulmonary embolism, TVT      2018-01-01       118
#
#    status_not_yet_recruiting  status_recruiting  \
# 0                          8                 24
#
#    status_enrolling_by_invitation  status_active_not_recruiting  \
# 0                               1                             9
#
#    status_suspended  status_terminated  ...  org_other  org_other_gov  \
# 0                 1                  4  ...         72              2
#
#    phase_early_1  phase_not_applicable  phase_1  phase_2  phase_3  phase_4  \
# 0              0                    10        1       15       41       14
#
#    pm_results                                        conclusions
# 0         524   In analyses restricted to low-risk patients (...
#
# [1 rows x 28 columns]
